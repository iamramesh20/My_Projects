# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 =pd.read_csv("https://raw.githubusercontent.com/iamramesh20/My_Projects/main/GUVI/Task4/college_1.csv")
df2=pd.read_csv("https://raw.githubusercontent.com/iamramesh20/My_Projects/main/GUVI/Task4/college_2.csv")
df= pd.concat([df1,df2])
df
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
df3=df[df['CodeKata Score'] > 15000]
df3
df3.to_csv(r'D:\GitHub\My_Projects\GUVI\Task4\Exceeded_expectations.csv',index = False)

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
df4 = df.loc[(df['CodeKata Score'] < 15000) & (df['CodeKata Score'] > 10000)]
df4
df4.to_csv(r'D:\GitHub\My_Projects\GUVI\Task4\Reached_expectations.csv',index = False)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
df5= df.loc[(df['CodeKata Score'] < 10000) & (df['CodeKata Score'] > 7000)]
df5
df5.to_csv(r'D:\GitHub\My_Projects\GUVI\Task4\Needs_Improvement.csv',index = False)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df6= df[df['CodeKata Score'] < 7000]
df6
df5.to_csv(r'D:\GitHub\My_Projects\GUVI\Task4\Unsatisfactory.csv',index = False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df['Difference_from_last_week'] = df['CodeKata Score'] - df['Previous Geekions']
df.tail(10)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 25       SHAIK DANISH    -1.0    0.0               4050            4820
# 26          sridhar.s    -1.0    0.0               3860            4440
# 27  Vimalesh Fernando    -1.0    0.0               4170            4170
# 28      M.Karthikeyan    -1.0    4.0               4020            4020
# 29          Abishak s    -1.0   35.0               3220            3220
# 30      praveen raj j    24.0    0.0               2380            2380
# 31         AMARNATH D    -1.0   12.0               1890            1890
# 32               bala    32.0    0.0               1720            1720
# 33               XY Z    -1.0   -1.0                  0               0
# 34          Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 25           Computer Science and Engineering     770       43.0
# ...

# %% [markdown]
# ###### No of students participated

# %%
df[df['CodeKata Score'] > 0]
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 28  M.Karthikeyan    -1.0    4.0               4020            4020
# 29      Abishak s    -1.0   35.0               3220            3220
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df['python_en'].mean()
# Out:
# 29.65714285714286

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.sort_values('Rising', ascending=False).head(3)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
# 2         Computer Science and Engineering    2000       55.0
#
#     computational_thinking  Difference_from_last_week
# 8                      0.0                       3140
# 18                     0.0                       2000
# 2                      6.0                       2000

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values('Rising', ascending=False).head(3)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
# 2         Computer Science and Engineering    2000       55.0
#
#     computational_thinking  Difference_from_last_week
# 8                      0.0                       3140
# 18                     0.0                       2000
# 2                      6.0                       2000

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
score = df['CodeKata Score'].groupby(df.Department).sum()
plt.axis('equal');
plt.title('Dept wise codekata performance')
plt.pie(sums, labels = score.index,shadow = True,startangle = 90);
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df1 = df.groupby(by = 'Department').max('CodeKata Score')
df1
plt.barh(df1.index, df1['CodeKata Score'])
plt.xlabel('CodeKata_Score')
plt.ylabel('Department')
plt.title('Department wise Toppers')
plt.show()
